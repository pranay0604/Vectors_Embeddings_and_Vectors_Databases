# %%
# !pip install langchain-groq
# Out:
# ...
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.2/603.2 kB 10.3 MB/s eta 0:00:00
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# ...
#   Attempting uninstall: h11
#     Found existing installation: h11 0.16.0
#     Uninstalling h11-0.16.0:
#       Successfully uninstalled h11-0.16.0
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.0.5
#     Uninstalling langchain-core-1.0.5:
#       Successfully uninstalled langchain-core-1.0.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# wsproto 1.3.1 requires h11<1,>=0.16.0, but you have h11 0.14.0 which is incompatible.
# ...

# %%
from langchain_groq import ChatGroq

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    api_key="GROQ_API_KEY",
    model="llama-3.3-70b-versatile",
    temperature=0,
    max_tokens=None
)

# %%
llm.invoke("Tell me about Sachin Tendulkar")
# Out:
# AIMessage(content='Sachin Ramesh Tendulkar is a former Indian international cricketer widely regarded as one of the greatest batsmen in the history of the sport. He is often referred to as the "God of Cricket" or the "Master Blaster."\n\n**Early Life and Career**\n\nBorn on April 24, 1973, in Mumbai, India, Sachin Tendulkar began playing cricket at a young age. He attended Sharadashram Vidyamandir School, where he was coached by Ramakant Achrekar, a renowned cricket coach. Tendulkar\'s talent and dedication earned him a spot in the Indian national team at the age of 16.\n\n**International Career**\n\nSachin Tendulkar made his international debut in 1989 against Pakistan in Karachi. He went on to play for India in 664 international matches, including 200 Test matches and 464 One Day Internationals (ODIs). During his career, he scored:\n\n* 15,921 runs in Test cricket, with 51 centuries and 68 half-centuries\n* 18,426 runs in ODIs, with 49 centuries and 96 half-centuries\n\n**Awards an
# ...

# %%
llm.invoke("Tell me about Sachin Tendulkar").content
# Out:
# 'Sachin Ramesh Tendulkar is a former Indian international cricketer widely regarded as one of the greatest batsmen in the history of the sport. He is often referred to as the "God of Cricket" or the "Master Blaster."\n\n**Early Life and Career**\n\nBorn on April 24, 1973, in Mumbai, India, Sachin Tendulkar began playing cricket at a young age. He attended Sharadashram Vidyamandir School, where he was coached by Ramakant Achrekar, a renowned cricket coach. Tendulkar\'s talent and dedication earned him a spot in the Indian national team at the age of 16.\n\n**International Career**\n\nSachin Tendulkar made his international debut in 1989 against Pakistan in a Test match. He went on to play 664 international matches, including 200 Test matches and 464 One-Day Internationals (ODIs). During his career, he scored:\n\n* 15,921 runs in Test matches at an average of 53.06\n* 18,426 runs in ODIs at an average of 44.83\n\nTendulkar holds numerous records in international cricket, including:\n\n
# ...

# %%
print(llm.invoke("Tell me about Sachin Tendulkar").content)
# Out:
# Sachin Ramesh Tendulkar is a former Indian international cricketer widely regarded as one of the greatest batsmen in the history of the sport. He is often referred to as the "God of Cricket" or the "Master Blaster."
#
# **Early Life and Career**
#
# Born on April 24, 1973, in Mumbai, India, Sachin Tendulkar began playing cricket at a young age. He attended Sharadashram Vidyamandir School, where he was coached by Ramakant Achrekar, a renowned cricket coach. Tendulkar's talent and dedication earned him a spot in the Indian national team at the age of 16.
#
# **International Career**
#
# Sachin Tendulkar made his international debut in 1989 against Pakistan in Karachi. He went on to play for India in 664 international matches, including 200 Test matches and 464 One Day Internationals (ODIs). During his career, he scored:
#
# * 15,921 runs in Test cricket, with 51 centuries and 68 half-centuries
# * 18,426 runs in ODIs, with 49 centuries and 96 half-centuries
#
# ...

# %%
# !pip install langchain-core

# %%
import langchain_core

# %%
dir(langchain_core)
# Out:
# ['VERSION',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_api',
#  '_import_utils',
#  'caches',
#  'callbacks',
#  'env',
#  'exceptions',
#  'globals',
#  'language_models',
#  'load',
#  'messages',
#  'output_parsers',
#  'outputs',
#  'prompt_values',
#  'rate_limiters',
#  'runnables',
#  'surface_langchain_beta_warnings',
#  'surface_langchain_deprecation_warnings',
#  'tools',
#  'tracers',
#  'utils',
#  'version']

# %%
from langchain_core.output_parsers import StrOutputParser

# %%
from langchain_groq import ChatGroq
from langchain_core.output_parsers import StrOutputParser

llm = ChatGroq(
    api_key="GROQ_API_KEY",
    model="llama-3.3-70b-versatile",
    temperature=0,
    max_tokens=None
)

parser = StrOutputParser()

# %%
print(llm.invoke("Tell me about Rohit Sharma").content)
# Out:
# Rohit Sharma is an Indian international cricketer who is widely regarded as one of the most successful and dominant batsmen in the world. Here are some key facts about him:
#
# **Early Life and Career**
#
# Rohit Sharma was born on April 30, 1987, in Nagpur, Maharashtra, India. He started playing cricket at a young age and joined the Bharat Cricket Club in Mumbai. He made his first-class debut for Mumbai in 2006 and quickly rose through the ranks.
#
# **International Career**
#
# Rohit made his international debut for India in 2007, playing a T20I match against England. He made his ODI debut in 2007 and his Test debut in 2013. Since then, he has become a regular member of the Indian team in all three formats of the game.
#
# **Achievements**
#
# Rohit has achieved numerous records and milestones in his career, including:
#
# * Highest individual score in ODIs: 264 runs against Sri Lanka in 2014
# * Most centuries in ODIs: 41 centuries
# * Most sixes in ODIs: 244 sixes
# ...

# %%
from langchain_groq import ChatGroq
from langchain_core.output_parsers import StrOutputParser

llm = ChatGroq(
    api_key="GROQ_API_KEY",
    model="llama-3.3-70b-versatile",
    temperature=0,
    max_tokens=None
)

parser = StrOutputParser()

chain = llm|parser

response = chain.invoke("Tell about a poem on kid")
print(response)
# Out:
# Here's a short poem about a kid:
#
# "A Little Bundle of Joy"
#
# With eyes so bright and a smile so wide,
# A little kid runs, with energy inside.
# Their laughter echoes, contagious and free,
# A bundle of joy, for you and me.
#
# Their tiny hands, so small and new,
# Grasp yours tightly, with a love so true.
# Their curious mind, with questions so bright,
# Explores the world, with wonder and delight.
#
# With every step, they take with glee,
# A new discovery, for them to see.
# Their imagination, runs wild and free,
# A magical world, for them to be.
#
# This little kid, with a heart so pure,
# Brings joy to all, with their presence so sure.
# Their smile can light, up a darkest night,
# And fill our hearts, with love and delight.
#
# This poem is a celebration of the innocence and wonder of childhood. It describes the energy, curiosity, and joy that kids bring to the world. The poem also highlights the importance of childhood and the impact that kids have on our lives.

# %%
LANGCHAIN_API_KEY="LANGSMITH_API_KEY"
LANGCHAIN_PROJECT="test"

# %%
import os
os.environ["LANGSMITHAPI_KEY"] = "LANGSMITH_API_KEY"
os.environ["LANGSMITH_PROJECT"] = "test"
os.environ["LANGSMITH_TRACING"] = "true"
GROQ_API_KEY="GROQ_API_KEY"

from langchain_groq import ChatGroq
from langchain_core.output_parsers import StrOutputParser

llm = ChatGroq(
    api_key="GROQ_API_KEY",
    model="llama-3.3-70b-versatile",
    temperature=0,
    max_tokens=None
)

parser = StrOutputParser()

chain = llm|parser

response = chain.invoke("Tell about a Virat Kohli")
print(response)
# Out:
# Virat Kohli is a renowned Indian international cricketer who has been one of the most dominant batsmen in the world for over a decade. Here are some key facts about him:
#
# **Early Life and Career**
#
# Virat Kohli was born on November 5, 1988, in Delhi, India. He developed a passion for cricket at a young age and began playing at the West Delhi Cricket Academy. Kohli's talent and dedication earned him a spot in the Delhi Under-15 team, and he eventually made his first-class debut for Delhi in 2006.
#
# **International Career**
#
# Kohli made his international debut for India in 2008, playing in a One-Day International (ODI) against Sri Lanka. He quickly established himself as a key player in the Indian team, known for his aggressive batting style and exceptional fielding skills. Kohli has since become one of the most successful batsmen in Indian cricket history, with numerous records and accolades to his name.
#
# **Achievements and Records**
#
# ...
